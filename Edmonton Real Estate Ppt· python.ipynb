# %%
# !pip install python-pptx
# Out:
# ...
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/4.0 MB 322.4 kB/s eta 0:00:11
#    ----- ---------------------------------- 0.5/4.0 MB 322.4 kB/s eta 0:00:11
#    ----- ---------------------------------- 0.5/4.0 MB 322.4 kB/s eta 0:00:11
#    ----- ---------------------------------- 0.5/4.0 MB 322.4 kB/s eta 0:00:11
#    ----- ---------------------------------- 0.5/4.0 MB 322.4 kB/s eta 0:00:11
#    ------- -------------------------------- 0.8/4.0 MB 270.5 kB/s eta 0:00:12
#    ------- -------------------------------- 0.8/4.0 MB 270.5 kB/s eta 0:00:12
#    ------- -------------------------------- 0.8/4.0 MB 270.5 kB/s eta 0:00:12
# ...

# %%
from pptx import Presentation
from pptx.util import Inches, Pt

# Example: create a new presentation
prs = Presentation()

# Add a title slide
slide_layout = prs.slide_layouts[0]
slide = prs.slides.add_slide(slide_layout)
slide.shapes.title.text = "Edmonton Real Estate Capstone"
slide.placeholders[1].text = "Data Preparation, Analysis & Insights"

# Save
prs.save("edmonton_real_estate_capstone.pptx")

# %%
# -----------------------------------
# Slide 2: Project Objective
# -----------------------------------
slide_layout = prs.slide_layouts[1]  # Title + Content layout
slide = prs.slides.add_slide(slide_layout)
slide.shapes.title.text = "Project Objective"
slide.placeholders[1].text = (
    "Goal: Help agents & sellers in Edmonton determine if a property will stay on the market > 60 days.\n\n"
    "Business benefits:\n"
    "- Adjust pricing strategies\n"
    "- Reduce time on market\n"
    "- Avoid expectation gaps\n"
    "- Improve selling efficiency"
)

# -----------------------------------
# Slide 3: Datasets Loaded
# -----------------------------------
slide = prs.slides.add_slide(slide_layout)
slide.shapes.title.text = "Step 1: Data Loading"
slide.placeholders[1].text = (
    "Datasets:\n"
    "- Active Listings: Properties currently on the market\n"
    "- Sold Listings: Properties already sold\n\n"
    "Code placeholder: Insert code screenshot here"
)

# -----------------------------------
# Slide 4: Duplicate Analysis
# -----------------------------------
slide = prs.slides.add_slide(slide_layout)
slide.shapes.title.text = "Step 2: Duplicate Analysis"
slide.placeholders[1].text = (
    "We check for:\n"
    "- Full-row duplicates\n"
    "- Duplicate listing IDs\n\n"
    "Purpose:\n"
    "Ensure data integrity and avoid bias in analysis.\n\n"
    "Code placeholder: Insert code screenshot here"
)

# -----------------------------------
# Slide 5: Remove Duplicates
# -----------------------------------
slide = prs.slides.add_slide(slide_layout)
slide.shapes.title.text = "Step 3: Remove Duplicates"
slide.placeholders[1].text = (
    "Removed duplicates to:\n"
    "- Keep each property unique\n"
    "- Prevent data leakage\n"
    "- Ensure accurate modeling\n\n"
    "Code placeholder: Insert code screenshot here"
)

# -----------------------------------
# Slide 6: Edmonton Filtering
# -----------------------------------
slide = prs.slides.add_slide(slide_layout)
slide.shapes.title.text = "Step 4: Filter Edmonton Only"
slide.placeholders[1].text = (
    "Filtered datasets to Edmonton listings using 'area_city'.\n"
    "Focuses analysis on target market and aligns with project objectives.\n\n"
    "Code placeholder: Insert code screenshot here"
)

# -----------------------------------
# Slide 7: Target Variable Creation
# -----------------------------------
slide = prs.slides.add_slide(slide_layout)
slide.shapes.title.text = "Step 5: Create Target Variable"
slide.placeholders[1].text = (
    "Target: stale_listing (1 if DOM > 60 days, 0 otherwise)\n"
    "Only sold listings have DOM, so we use sold_df.\n\n"
    "Code placeholder: Insert code screenshot here"
)

# -----------------------------------
# Slide 8: Pricing Relative to Neighborhood
# -----------------------------------
slide = prs.slides.add_slide(slide_layout)
slide.shapes.title.text = "Step 6: Pricing vs Neighborhood"
slide.placeholders[1].text = (
    "Calculate price_gap and price_gap_pct to see how over/underpriced a property is.\n"
    "Helps understand impact of pricing on time on market.\n\n"
    "Code placeholder: Insert code screenshot here"
)

# -----------------------------------
# Slide 9: Price Gap Analysis
# -----------------------------------
slide = prs.slides.add_slide(slide_layout)
slide.shapes.title.text = "Step 7: Price Gap & DOM"
slide.placeholders[1].text = (
    "Scatter plot DOM vs Price Gap (%)\n"
    "Correlation between price gap and DOM: 0.019 → almost no linear relationship\n\n"
    "Visual placeholder: Insert scatter plot screenshot here"
)

# -----------------------------------
# Slide 10: Numeric Feature Correlation
# -----------------------------------
slide = prs.slides.add_slide(slide_layout)
slide.shapes.title.text = "Step 8: Numeric Features & Staleness"
slide.placeholders[1].text = (
    "Correlation of numeric features with stale_listing:\n"
    "- Floor area: 0.052\n"
    "- List price: 0.047\n"
    "- Price gap: 0.027\n"
    "- Price gap %: 0.022\n"
    "- Baths: 0.015\n"
    "- Year built: -0.034\n"
    "- Beds: -0.059\n\n"
    "Insight: Numeric features alone are weak predictors of staleness.\n\n"
    "Visual placeholder: Optional bar chart of correlations"
)

# -----------------------------------
# Slide 11: Categorical Features
# -----------------------------------
slide = prs.slides.add_slide(slide_layout)
slide.shapes.title.text = "Step 9: Categorical Features"
slide.placeholders[1].text = (
    "Stale rates by category (top examples):\n"
    "- Style: Studios 44% stale, Modular 40%\n"
    "- Parking: Complex setups 100% stale\n"
    "- Ensuite: Yes 28%, No 23%\n\n"
    "Insight: Property type and features strongly influence DOM.\n\n"
    "Visual placeholder: Insert bar plots or tables"
)

# -----------------------------------
# Slide 12: Overpriced Listings
# -----------------------------------
slide = prs.slides.add_slide(slide_layout)
slide.shapes.title.text = "Business Insight: Overpriced Listings"
slide.placeholders[1].text = (
    "- 48.1% of listings above neighborhood average\n"
    "- Overpriced properties stay longer on market\n"
    "- Recommendation: Price in line with neighborhood trends\n\n"
    "Visual placeholder: Insert table or plot"
)

# -----------------------------------
# Slide 13: Seasonal Patterns
# -----------------------------------
slide = prs.slides.add_slide(slide_layout)
slide.shapes.title.text = "Business Insight: Seasonal Sales"
slide.placeholders[1].text = (
    "- Average DOM by month\n"
    "- Jan & Dec highest DOM, May fastest\n"
    "- Recommendation: List in late spring/early summer\n\n"
    "Visual placeholder: Insert bar chart of DOM by month"
)

# -----------------------------------
# Slide 14: Feature Engineering
# -----------------------------------
slide = prs.slides.add_slide(slide_layout)
slide.shapes.title.text = "Step 10: Feature Engineering"
slide.placeholders[1].text = (
    "Derived features for modeling:\n"
    "- Price gap & %\n"
    "- Floor area per bedroom\n"
    "- Bed-to-bath ratio\n"
    "- Time features: month, season, year\n\n"
    "Code placeholder: Insert code screenshot here"
)

# -----------------------------------
# Slide 15: Spatial Enrichment
# -----------------------------------
slide = prs.slides.add_slide(slide_layout)
slide.shapes.title.text = "Step 11: Latitude & Longitude"
slide.placeholders[1].text = (
    "Convert full address to lat/lon using geopy and Nominatim.\n"
    "Sample of 1000 rows for geocoding to save time.\n\n"
    "Visual placeholder: Insert map or scatter plot of geocoded points"
)

# -----------------------------------
# Slide 16: Geocoding Validation
# -----------------------------------
slide = prs.slides.add_slide(slide_layout)
slide.shapes.title.text = "Step 12: Geocoding Validation"
slide.placeholders[1].text = (
    "- Missing latitude: 264\n"
    "- Missing longitude: 264\n"
    "- Summary: mean/25/50/75% of coordinates\n\n"
    "Insight: Most addresses mapped correctly, ready for spatial analysis\n\n"
    "Visual placeholder: Optional table of stats"
)

# -----------------------------------
# Slide 17: Map Visualization
# -----------------------------------
slide = prs.slides.add_slide(slide_layout)
slide.shapes.title.text = "Step 13: Map Visualization"
slide.placeholders[1].text = (
    "Scatter plot of geocoded properties across Edmonton.\n"
    "- Shows clusters and sparse areas\n"
    "- Helps identify popular neighborhoods\n\n"
    "Visual placeholder: Insert scatter plot screenshot"
)

# -----------------------------------
# Slide 18: Predictive Modeling Prep
# -----------------------------------
slide = prs.slides.add_slide(slide_layout)
slide.shapes.title.text = "Step 14: Modeling Preparation"
slide.placeholders[1].text = (
    "- Encode categorical variables (style, parking, community)\n"
    "- Merge internal + external features\n"
    "- Dataset ready for predictive modeling\n\n"
    "Code placeholder: Insert code screenshot here"
)

# -----------------------------------
# Slide 19: Business Insights Summary
# -----------------------------------
slide = prs.slides.add_slide(slide_layout)
slide.shapes.title.text = "Business Insights Summary"
slide.placeholders[1].text = (
    "1. Price matters, but not alone\n"
    "2. Seasonal timing affects DOM\n"
    "3. Property type & features strongly affect staleness\n"
    "4. Agents can guide sellers on pricing, presentation & timing\n\n"
    "Visual placeholder: Optional summary chart"
)

# -----------------------------------
# Slide 20: Next Steps
# -----------------------------------
slide = prs.slides.add_slide(slide_layout)
slide.shapes.title.text = "Next Steps"
slide.placeholders[1].text = (
    "- Finish EDA & business insights visualizations\n"
    "- Feature engineering and external data enrichment\n"
    "- Train predictive model (Random Forest)\n"
    "- Generate actionable recommendations for sellers\n"
    "- Risk scores & neighborhood heatmaps for staleness\n\n"
    "Visual placeholder: Optional diagrams or code"
)

# Save final presentation
prs.save("edmonton_real_estate_capstone_20slides.pptx")
print("✅ 20-slide presentation created successfully!")
# Out:
# ✅ 20-slide presentation created successfully!
